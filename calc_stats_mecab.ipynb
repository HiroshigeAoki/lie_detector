# %%
#data_dir = 'data/nested'
data_dir = 'data/nested_sample'

# %%
import pandas as pd
import numpy as np
from collections import Counter
from pandarallel import pandarallel
import MeCab
import oseti
from transformers import BertJapaneseTokenizer

tokenizer = BertJapaneseTokenizer.from_pretrained('cl-tohoku/bert-large-japanese', additional_special_tokens=['<person>'])
mecab_args = "-r /home/haoki/Documents/vscode-workplaces/lie_detector/project/tokenizer/mecab_userdic/mecabrc -d /usr/local/lib/mecab/dic/mecab-ipadic-neologd"

hedges = ['かも', 'かもしれん','そうかもしれない','かな','なのかな','あるかな','そうかな','っぽい','たぶん','多分','恐らく','めいた','ちょっと','すこし','少し']
self_references = ['私', '私自身','私的','私たち','私達','私見','私は羊','私について','私の主張','私事','私のように','私の部屋','実は私は','私ゃ','明日の私','私が死んでも','私どう','僕','僕自身','僕ら','僕たち','僕のこと','僕は思う','僕達','僕は君','下僕','僕が悪い','僕の話','老僕','ぼく','ぼくが','ぼくら','わたし','わたしゃ','わたしたち','俺','俺様','おれ','おれっち','あたし','あたしゃ','わし','わしゃ']
cognitive_words = ['おもう', '思う','思うに','考え','考える','かんがえる','かんがえ','かんがえなおす']


def feature_counter(nested_df):
    pandarallel.initialize()
    nested_df.loc[:, 'nested_utters'] = nested_df.loc[:, 'nested_utters'].parallel_apply(_feature_counter)
    col_names = ['num_morphemes', 'num_subwords', 'positive', 'negative', 'polarity', 'self_ref', 'cognitive', 'hedges', 'noun', 'verb', 'adjective', 'conjunction', 'particle']
    nested_df = player_feature_count(nested_df, col_names)
    return nested_df

def _feature_counter(df: pd.DataFrame):
    tagger = MeCab.Tagger(mecab_args)
    analyzer = oseti.Analyzer(mecab_args)
    parsed_utters_mecab = df.loc[:, 'raw_nested_utters'].apply(tagger.parse)
    parsed_utters_wordpiece = df.loc[:, 'raw_nested_utters'].apply(tokenizer.tokenize)
    count = {'num_morphemes': [], 'num_subwords': [], 'positive': [], 'negative': [], 'polarity': [], 'self_ref': [], 'cognitive': [], 'hedges': [], 'noun': [], 'verb': [], 'adjective': [], 'conjunction': [], 'particle': []}
    for (_, line), (_, parsed_line_mecab), parsed_line_wordpiece in zip(df.loc[:, 'raw_nested_utters'].items(), parsed_utters_mecab.items(), parsed_utters_wordpiece):
        polarity = analyzer.count_polarity(line) # 東北大の極性辞書を使って、polarityを計算
        count['positive'].append(sum([pol['positive'] for pol in polarity]))
        count['negative'].append(sum([pol['negative'] for pol in polarity]))
        matched_total = sum([pol['positive'] + pol['negative'] for pol in polarity])
        count['polarity'].append(sum([pol['positive'] - pol['negative'] for pol in polarity]) / matched_total if matched_total != 0 else 0) # average

        count['num_morphemes'].append(len(parsed_line_mecab.split('\n')) - 1) # exclude EOS
        count['num_subwords'].append(len(parsed_line_wordpiece))
        mors = [mor.split("\t")[0] for mor in parsed_line_mecab.split("\n")[:-2]] # 形態素のリスト。EOSトークン除外
        count['self_ref'].append(len([mor for mor in mors if mor in self_references]))
        count['cognitive'].append(len([mor for mor in mors if mor in cognitive_words]))
        count['hedges'].append(len([mor for mor in mors if mor in hedges]))

        pos = [mor.split("\t")[1].split(",")[0] for mor in parsed_line_mecab.split("\n")[:-2]] # 品詞をカウント
        pos_count = Counter(pos)
        count['noun'].append(pos_count['名詞'])
        count['verb'].append(pos_count['動詞'])
        count['adjective'].append(pos_count['形容詞'])
        count['conjunction'].append(pos_count['接続詞'])
        count['particle'].append(pos_count['助詞'])
    return pd.concat((df, pd.DataFrame(count)), axis=1)

def sum_mean_std(df, col_name):
    return (
        [np.sum(nested_utters_df.loc[:,col_name]) for nested_utters_df in df.loc[:,'nested_utters']],
        [np.mean(nested_utters_df.loc[:,col_name]) for nested_utters_df in df.loc[:,'nested_utters']],
        [np.std(nested_utters_df.loc[:,col_name]) for nested_utters_df in df.loc[:,'nested_utters']]
    )

def player_feature_count(df, col_names):
    for col_name in col_names:
        df[f"{col_name}_sum"], df[f"{col_name}_mean"], df[f"{col_name}_std"] = sum_mean_std(df, col_name)
    return df
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
train = pd.read_pickle(f'{data_dir}/train.pkl')
valid = pd.read_pickle(f'{data_dir}/valid.pkl')
test = pd.read_pickle(f'{data_dir}/test.pkl')

train = feature_counter(train)
valid = feature_counter(valid)
test = feature_counter(test)
# Out:
# INFO: Pandarallel will run on 112 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# INFO: Pandarallel will run on 112 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# INFO: Pandarallel will run on 112 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %%
train.head()
# Out:
#                                        nested_utters  num_utters  labels  \
# 0                                      raw_nested...          80       1
# 1                                      raw_nested...          53       0
# 2                                      raw_nested...          71       0
# 3                                      raw_nested...          55       0
# 4                                      raw_nested...          32       0
#
#    num_morphemes_sum  num_morphemes_mean  num_morphemes_std  num_subwords_sum  \
# 0               4660           58.250000          25.791714              5048
# 1               2594           48.943396          17.726874              2939
# 2               5284           74.422535          30.388407              5780
# 3               3690           67.090909          27.254539              4135
# 4               2459           76.843750          29.273612              2873
#
#    num_subwords_mean  num_subwords_std  positive_sum  ...  verb_std  \
# 0          63.100000         28.324724           111  ...  4.125833
# 1          55.452830         19.505748            64  ...  3.225036
# 2          81.408451         33.795398           148  ...  5.394201
# 3          75.181818         29.748700           103  ...  4.765787
# 4          89.781250         33.854223            59  ...  6.066606
#
#    adjective_sum  adjective_mean  adjective_std  conjunction_sum  \
# 0             65        0.812500       1.096514               40
# 1             54        1.018868       1.018518               15
# 2             87        1.225352       1.177215               40
# 3             75        1.363636       1.353294               12
# 4             70        2.187500       2.156929               17
#
#    conjunction_mean  conjunction_std  particle_sum  particle_mean  \
# 0          0.500000         0.758288          1134      14.175000
# 1          0.283019         0.527628           729      13.754717
# 2          0.563380         0.817630          1576      22.197183
# 3          0.218182         0.493260           997      18.127273
# 4          0.531250         0.749349           661      20.656250
#
#    particle_std
# 0      7.692163
# 1      6.024809
# 2      9.684632
# 3      8.946415
# 4      9.926635
#
# [5 rows x 42 columns]

# %%
def calc_stats(nested_df):
    player_num = len(nested_df)
    civil_num = nested_df.loc[:,'labels'].value_counts()[0]
    werewolf_num = nested_df.loc[:,'labels'].value_counts()[1]
    sum_utter_num = nested_df.loc[:,'num_utters'].sum()
    ave_utter_num = nested_df.loc[:,'num_utters'].mean()
    max_utter_num = nested_df.loc[:,'num_utters'].max()
    min_utter_num = nested_df.loc[:,'num_utters'].min()
    sum_mor_num = nested_df.loc[:,'num_morphemes_sum'].sum()
    ave_mor_num_per_player = nested_df.loc[:,'num_morphemes_sum'].mean()
    max_mor_num_per_player = nested_df.loc[:,'num_morphemes_sum'].max()
    min_mor_num_per_player = nested_df.loc[:,'num_morphemes_sum'].min()
    ave_mor_num_per_utter = sum_mor_num / sum_utter_num
    max_mor_num_per_utter = max([df.loc[:,'num_morphemes'].max() for df in nested_df.loc[:,'nested_utters']])
    min_mor_num_per_utter = min([df.loc[:,'num_morphemes'].min() for df in nested_df.loc[:,'nested_utters']])
    sum_sub_num = nested_df.loc[:,'num_subwords_sum'].sum()
    ave_sub_num_per_player = nested_df.loc[:,'num_subwords_sum'].mean()
    max_sub_num_per_player = nested_df.loc[:,'num_subwords_sum'].max()
    min_sub_num_per_player = nested_df.loc[:,'num_subwords_sum'].min()
    ave_sub_num_per_utter = sum_sub_num / sum_utter_num
    max_sub_num_per_utter = max([df.loc[:,'num_subwords'].max() for df in nested_df.loc[:,'nested_utters']])
    min_sub_num_per_utter = min([df.loc[:,'num_subwords'].min() for df in nested_df.loc[:,'nested_utters']])

    return [f'{player_num:,}({civil_num:,}/{werewolf_num:,})', sum_utter_num, ave_utter_num, max_utter_num, min_utter_num, sum_mor_num, ave_mor_num_per_player, max_mor_num_per_player, min_mor_num_per_player, ave_mor_num_per_utter, max_mor_num_per_utter, min_mor_num_per_utter, sum_sub_num, ave_sub_num_per_player, max_sub_num_per_player, min_sub_num_per_player, ave_sub_num_per_utter, max_sub_num_per_utter, min_sub_num_per_utter]


def make_stats_table(train, valid, test):
    index = ['プレイヤー数(人狼/市民)', '合計発話数', '平均発話数', '最大発話数', '最小発話数', 
                '形態素数合計', '1プレイヤーにおける平均形態素数', '1プレイヤーにおける最大形態素数', '1プレイヤーにおける最小形態素数', '1発話における平均形態素数', '1発話における最大形態素数', '1発話における最小形態素数', 
                'サブワード数合計', '1プレイヤーにおける平均サブワード数', '1プレイヤーにおける最大サブワード数', '1プレイヤーにおける最小サブワード数', '1発話における平均サブワード数', '1発話における最大サブワード数', '1発話における最小サブワード数']
    train_row = calc_stats(train)
    valid_row = calc_stats(valid)
    test_row = calc_stats(test)
    stats_table = pd.DataFrame({'train': train_row, 'valid': valid_row, 'test': test_row}, index=index)
    stats_table.iloc[1:] = stats_table.iloc[1:].applymap(lambda x: f'{x:,.2f}')

    return stats_table

# %%
stats_table = make_stats_table(train, valid, test)
display(stats_table)
stats_table.to_csv(f'{data_dir}/stats_mecab.csv')
# Out:
#                          train      valid       test
# プレイヤー数(人狼/市民)        42(21/21)     6(3/3)     6(3/3)
# 合計発話数                 3,555.00     255.00     558.00
# 平均発話数                    84.64      42.50      93.00
# 最大発話数                   134.00      94.00     116.00
# 最小発話数                    32.00      17.00      60.00
# 形態素数合計              252,024.00  16,352.00  40,035.00
# 1プレイヤーにおける平均形態素数      6,000.57   2,725.33   6,672.50
# 1プレイヤーにおける最大形態素数     11,455.00   5,183.00   7,478.00
# 1プレイヤーにおける最小形態素数      2,459.00   1,096.00   5,520.00
# 1発話における平均形態素数            70.89      64.13      71.75
# 1発話における最大形態素数           150.00     134.00     131.00
# 1発話における最小形態素数             8.00       9.00      10.00
# サブワード数合計            282,343.00  18,120.00  44,832.00
# 1プレイヤーにおける平均サブワード数    6,722.45   3,020.00   7,472.00
# 1プレイヤーにおける最大サブワード数   12,801.00   5,748.00   8,250.00
# 1プレイヤーにおける最小サブワード数    2,873.00   1,202.00   6,110.00
# 1発話における平均サブワード数          79.42      71.06      80.34
# 1発話における最大サブワード数         154.00     141.00     151.00
# 1発話における最小サブワード数          10.00      14.00      15.00

# %%
train = train.drop('nested_utters', axis=1)
display(train.corr().style.background_gradient(axis=None))
# Out:
# <style type="text/css">
# #T_ba13b_row0_col0, #T_ba13b_row1_col1, #T_ba13b_row2_col2, #T_ba13b_row3_col3, #T_ba13b_row4_col4, #T_ba13b_row5_col5, #T_ba13b_row6_col6, #T_ba13b_row7_col7, #T_ba13b_row8_col8, #T_ba13b_row9_col9, #T_ba13b_row10_col10, #T_ba13b_row11_col11, #T_ba13b_row12_col12, #T_ba13b_row13_col13, #T_ba13b_row14_col14, #T_ba13b_row15_col15, #T_ba13b_row16_col16, #T_ba13b_row17_col17, #T_ba13b_row18_col18, #T_ba13b_row19_col19, #T_ba13b_row20_col20, #T_ba13b_row21_col21, #T_ba13b_row22_col22, #T_ba13b_row23_col23, #T_ba13b_row24_col24, #T_ba13b_row25_col25, #T_ba13b_row26_col26, #T_ba13b_row27_col27, #T_ba13b_row28_col28, #T_ba13b_row29_col29, #T_ba13b_row30_col30, #T_ba13b_row31_col31, #T_ba13b_row32_col32, #T_ba13b_row33_col33, #T_ba13b_row34_col34, #T_ba13b_row35_col35, #T_ba13b_row36_col36, #T_ba13b_row37_col37 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_ba13b_row0_col1, #T_ba13b_row1_col0, #T_ba13b_row1_col8, #T_ba13b_row1_col10, #T_ba13b_row1_col14, #T_ba13b_row1_col16, #T_ba13b_row1_col31, #T_ba13b_row1_col35, #T_ba13b_row8_col1, #T_ba13b_row9_col37, #T_ba13b_row10_col1, #T_ba13b_row14_col1, #T_ba13b_row16_col1, #T_ba13b_row17_col37, #T_ba13b_row21_col37, #T_ba13b_row31_col1, #T_ba13b_row35_col1, #T_ba13b_row37_col9, #T_ba13b_row37_col17, #T_ba13b_row37_col21 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_ba13b_row0_col2, #T_ba13b_row2_col0, #T_ba13b_row2_col29, #T_ba13b_row3_col27, #T_ba13b_row15_col16, #T_ba13b_row16_col15, #T_ba13b_row26_col29, #T_ba13b_row27_col3, #T_ba13b_row27_col36, #T_ba13b_row29_col2, #T_ba13b_row29_col26, #T_ba13b_row36_col27 {
#   background-color: #03446a;
#   color: #f1f1f1;
# }
# #T_ba13b_row0_col3, #T_ba13b_row3_col0, #T_ba13b_row6_col20, #T_ba13b_row10_col31, #T_ba13b_row18_col20, #T_ba13b_row18_col23, #T_ba13b_row20_col6, #T_ba13b_row20_col18, #T_ba13b_row23_col18, #T_ba13b_row24_col34, #T_ba13b_row26_col34, #T_ba13b_row31_col10, #T_ba13b_row34_col24, #T_ba13b_row34_col26 {
#   background-color: #308cbe;
#   color: #f1f1f1;
# }
# #T_ba13b_row0_col4, #T_ba13b_row1_col5, #T_ba13b_row1_col7, #T_ba13b_row4_col0, #T_ba13b_row4_col34, #T_ba13b_row5_col1, #T_ba13b_row7_col1, #T_ba13b_row11_col25, #T_ba13b_row12_col30, #T_ba13b_row14_col25, #T_ba13b_row14_col37, #T_ba13b_row15_col37, #T_ba13b_row20_col37, #T_ba13b_row25_col11, #T_ba13b_row25_col14, #T_ba13b_row26_col37, #T_ba13b_row30_col12, #T_ba13b_row34_col4, #T_ba13b_row37_col14, #T_ba13b_row37_col15, #T_ba13b_row37_col20, #T_ba13b_row37_col26 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_ba13b_row0_col5, #T_ba13b_row3_col6, #T_ba13b_row5_col0, #T_ba13b_row6_col3 {
#   background-color: #034d79;
#   color: #f1f1f1;
# }
# #T_ba13b_row0_col6, #T_ba13b_row0_col34, #T_ba13b_row2_col22, #T_ba13b_row6_col0, #T_ba13b_row7_col32, #T_ba13b_row18_col34, #T_ba13b_row19_col34, #T_ba13b_row22_col2, #T_ba13b_row32_col7, #T_ba13b_row34_col0, #T_ba13b_row34_col18, #T_ba13b_row34_col19 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
# }
# #T_ba13b_row0_col7, #T_ba13b_row3_col15, #T_ba13b_row4_col7, #T_ba13b_row5_col21, #T_ba13b_row7_col0, #T_ba13b_row7_col4, #T_ba13b_row10_col37, #T_ba13b_row15_col3, #T_ba13b_row21_col5, #T_ba13b_row37_col10 {
#   background-color: #549cc7;
#   color: #f1f1f1;
# }
# #T_ba13b_row0_col8, #T_ba13b_row8_col0, #T_ba13b_row9_col24, #T_ba13b_row24_col9 {
#   background-color: #034e7b;
#   color: #f1f1f1;
# }
# #T_ba13b_row0_col9, #T_ba13b_row0_col24, #T_ba13b_row5_col19, #T_ba13b_row8_col33, #T_ba13b_row9_col0, #T_ba13b_row9_col34, #T_ba13b_row19_col5, #T_ba13b_row21_col31, #T_ba13b_row22_col31, #T_ba13b_row23_col33, #T_ba13b_row24_col0, #T_ba13b_row29_col33, #T_ba13b_row31_col21, #T_ba13b_row31_col22, #T_ba13b_row33_col8, #T_ba13b_row33_col23, #T_ba13b_row33_col29, #T_ba13b_row34_col9 {
#   background-color: #348ebf;
#   color: #f1f1f1;
# }
# #T_ba13b_row0_col10, #T_ba13b_row10_col0, #T_ba13b_row18_col33, #T_ba13b_row19_col32, #T_ba13b_row30_col34, #T_ba13b_row32_col19, #T_ba13b_row33_col18, #T_ba13b_row34_col30 {
#   background-color: #4094c3;
#   color: #f1f1f1;
# }
# #T_ba13b_row0_col11, #T_ba13b_row3_col4, #T_ba13b_row4_col3, #T_ba13b_row4_col36, #T_ba13b_row11_col0, #T_ba13b_row36_col4 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_ba13b_row0_col12, #T_ba13b_row2_col11, #T_ba13b_row2_col12, #T_ba13b_row11_col2, #T_ba13b_row11_col23, #T_ba13b_row11_col26, #T_ba13b_row12_col0, #T_ba13b_row12_col2, #T_ba13b_row12_col26, #T_ba13b_row13_col25, #T_ba13b_row23_col11, #T_ba13b_row25_col13, #T_ba13b_row26_col11, #T_ba13b_row26_col12 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_ba13b_row0_col13, #T_ba13b_row10_col12, #T_ba13b_row12_col10, #T_ba13b_row13_col0, #T_ba13b_row13_col14, #T_ba13b_row14_col13 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_ba13b_row0_col14, #T_ba13b_row7_col10, #T_ba13b_row10_col7, #T_ba13b_row14_col0, #T_ba13b_row18_col27, #T_ba13b_row27_col18 {
#   background-color: #0570b0;
#   color: #f1f1f1;
# }
# #T_ba13b_row0_col15, #T_ba13b_row14_col31, #T_ba13b_row15_col0, #T_ba13b_row15_col17, #T_ba13b_row17_col15, #T_ba13b_row31_col14 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_ba13b_row0_col16, #T_ba13b_row0_col21, #T_ba13b_row0_col25, #T_ba13b_row7_col16, #T_ba13b_row10_col16, #T_ba13b_row14_col22, #T_ba13b_row15_col30, #T_ba13b_row16_col0, #T_ba13b_row16_col7, #T_ba13b_row16_col10, #T_ba13b_row21_col0, #T_ba13b_row22_col14, #T_ba13b_row25_col0, #T_ba13b_row30_col15 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_ba13b_row0_col17, #T_ba13b_row2_col20, #T_ba13b_row4_col28, #T_ba13b_row17_col0, #T_ba13b_row20_col2, #T_ba13b_row20_col35, #T_ba13b_row28_col4, #T_ba13b_row32_col33, #T_ba13b_row33_col32, #T_ba13b_row35_col20 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_ba13b_row0_col18, #T_ba13b_row8_col21, #T_ba13b_row18_col0, #T_ba13b_row21_col8, #T_ba13b_row31_col33, #T_ba13b_row31_col34, #T_ba13b_row33_col31, #T_ba13b_row34_col31 {
#   background-color: #569dc8;
#   color: #f1f1f1;
# }
# #T_ba13b_row0_col19, #T_ba13b_row2_col21, #T_ba13b_row7_col22, #T_ba13b_row19_col0, #T_ba13b_row21_col2, #T_ba13b_row22_col7 {
#   background-color: #529bc7;
#   color: #f1f1f1;
# }
# #T_ba13b_row0_col20, #T_ba13b_row6_col30, #T_ba13b_row8_col20, #T_ba13b_row20_col0, #T_ba13b_row20_col8, #T_ba13b_row30_col6, #T_ba13b_row30_col36, #T_ba13b_row36_col30 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_ba13b_row0_col22, #T_ba13b_row6_col12, #T_ba13b_row12_col6, #T_ba13b_row15_col24, #T_ba13b_row16_col26, #T_ba13b_row16_col35, #T_ba13b_row22_col0, #T_ba13b_row24_col15, #T_ba13b_row26_col16, #T_ba13b_row35_col16 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
# }
# #T_ba13b_row0_col23, #T_ba13b_row8_col29, #T_ba13b_row23_col0, #T_ba13b_row29_col8 {
#   background-color: #034871;
#   color: #f1f1f1;
# }
# #T_ba13b_row0_col26, #T_ba13b_row0_col35, #T_ba13b_row5_col29, #T_ba13b_row18_col19, #T_ba13b_row19_col18, #T_ba13b_row23_col29, #T_ba13b_row26_col0, #T_ba13b_row29_col5, #T_ba13b_row29_col23, #T_ba13b_row35_col0 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_ba13b_row0_col27, #T_ba13b_row3_col14, #T_ba13b_row5_col31, #T_ba13b_row6_col21, #T_ba13b_row7_col18, #T_ba13b_row10_col18, #T_ba13b_row14_col3, #T_ba13b_row14_col27, #T_ba13b_row14_col36, #T_ba13b_row17_col33, #T_ba13b_row18_col7, #T_ba13b_row18_col10, #T_ba13b_row18_col31, #T_ba13b_row21_col6, #T_ba13b_row22_col24, #T_ba13b_row24_col22, #T_ba13b_row27_col0, #T_ba13b_row27_col14, #T_ba13b_row31_col5, #T_ba13b_row31_col18, #T_ba13b_row33_col17, #T_ba13b_row36_col14 {
#   background-color: #3991c1;
#   color: #f1f1f1;
# }
# #T_ba13b_row0_col28, #T_ba13b_row0_col31, #T_ba13b_row2_col28, #T_ba13b_row3_col25, #T_ba13b_row8_col25, #T_ba13b_row8_col28, #T_ba13b_row16_col24, #T_ba13b_row24_col16, #T_ba13b_row25_col3, #T_ba13b_row25_col8, #T_ba13b_row28_col0, #T_ba13b_row28_col2, #T_ba13b_row28_col8, #T_ba13b_row31_col0 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_ba13b_row0_col29, #T_ba13b_row24_col27, #T_ba13b_row27_col24, #T_ba13b_row29_col0 {
#   background-color: #03517e;
#   color: #f1f1f1;
# }
# #T_ba13b_row0_

# %%
import pandas_profiling
pandas_profiling.ProfileReport(train)
# Out:
# Summarize dataset:   0%|          | 0/51 [00:00<?, ?it/s]
